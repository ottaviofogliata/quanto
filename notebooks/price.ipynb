# %% [markdown]
# # Pricing Notebook

# %%
from quanto.pricing import monte_carlo, quantum_qaefrom quanto.config import load_configcfg = load_config('examples/config.yaml')

# %%
# Classical pricing for SPYres_classical = monte_carlo.price('SPY', 30, '-5%', cfg)res_classical

# %%
# Quantum-simulated pricingres_quantum = quantum_qae.price('SPY', 30, '-5%', cfg)res_quantum

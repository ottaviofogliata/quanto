# %% [markdown]
# # Pricing Notebook

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path('..')/'src'))
from quanto.pricing import monte_carlo, quantum_qae
from quanto.config import load_config
cfg = load_config(pathlib.Path('..')/'examples/config.yaml')

# %%
# Classical pricing for SPY
res_classical = monte_carlo.price('SPY', 30, '-5%', cfg)
res_classical

# %%
# Quantum-simulated pricing
res_quantum = quantum_qae.price('SPY', 30, '-5%', cfg)
res_quantum

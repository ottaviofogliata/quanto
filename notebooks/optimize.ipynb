# %% [markdown]
# # Optimization Notebook

# %%
from quanto.optimize import milp, qaoafrom quanto.config import load_configcfg = load_config('examples/config.yaml')

# %%
# Attempt quantum-inspired optimization, fallback to MILPres = qaoa.optimize(cfg) or milp.optimize(cfg)res

# %% [markdown]
# # Optimization Notebook

# %%
import sys, pathlib
sys.path.append(str(pathlib.Path('..')/'src'))
from quanto.optimize import milp, qaoa
from quanto.config import load_config
cfg = load_config(pathlib.Path('..')/'examples/config.yaml')

# %%
# Attempt quantum-inspired optimization, fallback to MILP
res = qaoa.optimize(cfg) or milp.optimize(cfg)
res

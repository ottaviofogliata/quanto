# %% [markdown]
# # Hilbert Curve Demo Notebook

# %%
from quanto.config import load_configfrom quanto.portfolio import hilbertimport numpy as npimport matplotlib.pyplot as pltcfg = load_config('examples/config.yaml')basis = cfg.experiment['universe']amps = np.full(len(basis), 1.0/len(basis))portfolio = hilbert.HilbertPortfolio(basis, amps)portfolio.pretty()

# %%
# Visualize probabilitiesplt.bar(basis, portfolio.probs())plt.ylabel('Probability')plt.title('Hilbert Portfolio Probabilities')

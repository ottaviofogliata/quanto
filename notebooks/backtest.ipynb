# %% [markdown]
# # Backtest Notebook

# %%
from quanto.config import load_configfrom quanto.backtest.engine import run_backtestcfg = load_config('examples/config.yaml')

# %%
summary = run_backtest(cfg, source='random', ticker='SPY')summary

# %%
# Example equity curve plotimport matplotlib.pyplot as pltplt.plot(summary['equity_curve'])plt.title('Equity Curve')
